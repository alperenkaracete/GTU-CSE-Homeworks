# %%
#pip install mysql-connector-python

# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
import mysql.connector

# %%
def open_new_window_customer():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_name = Label(new_window, text="Name:")
    label_name.grid(row=0, column=0, padx=10, pady=5)
    entry_name = Entry(new_window)
    entry_name.grid(row=0, column=1)

    label_surname = Label(new_window, text="Surname:")
    label_surname.grid(row=1, column=0, padx=10, pady=5)
    entry_surname = Entry(new_window)
    entry_surname.grid(row=1, column=1)

    label_contact = Label(new_window, text="Contact Details:")
    label_contact.grid(row=2, column=0, padx=10, pady=5)
    entry_contact = Entry(new_window)
    entry_contact.grid(row=2, column=1)

    label_gender = Label(new_window, text="Gender:")
    label_gender.grid(row=3, column=0, padx=10, pady=5)
    entry_gender = Entry(new_window)
    entry_gender.grid(row=3, column=1)

    label_reg_date = Label(new_window, text="Birthday:")
    label_reg_date.grid(row=4, column=0, padx=10, pady=5)
    entry_reg_date = Entry(new_window)
    entry_reg_date.grid(row=4, column=1)

    label_address = Label(new_window, text="Address:")
    label_address.grid(row=5, column=0, padx=10, pady=5)
    entry_address = Entry(new_window)
    entry_address.grid(row=5, column=1)

    # Create Tkinter button to save the customer details
    button_save = Button(new_window, text="Save", command=lambda: save_customer(
        entry_name.get(), entry_surname.get(), entry_contact.get(), entry_gender.get(),
        entry_reg_date.get(), entry_address.get()
    ))
    button_save.grid(row=6, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_booking():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_cust_id = Label(new_window, text="Customer ID:")
    label_cust_id.grid(row=0, column=0, padx=10, pady=5)
    entry_cust_id = Entry(new_window)
    entry_cust_id.grid(row=0, column=1)

    label_bus_id = Label(new_window, text="Bus ID:")
    label_bus_id.grid(row=1, column=0, padx=10, pady=5)
    entry_bus_id = Entry(new_window)
    entry_bus_id.grid(row=1, column=1)

    label_hotel_id = Label(new_window, text="Hotel ID:")
    label_hotel_id.grid(row=2, column=0, padx=10, pady=5)
    entry_hotel_id = Entry(new_window)
    entry_hotel_id.grid(row=2, column=1)

    label_booking_date = Label(new_window, text="Booking Date:")
    label_booking_date.grid(row=3, column=0, padx=10, pady=5)
    entry_booking_date = Entry(new_window)
    entry_booking_date.grid(row=3, column=1)

    label_total_day = Label(new_window, text="Total Day:")
    label_total_day.grid(row=4, column=0, padx=10, pady=5)
    entry_total_day = Entry(new_window)
    entry_total_day.grid(row=4, column=1)

    label_start_date = Label(new_window, text="Start Date:")
    label_start_date.grid(row=5, column=0, padx=10, pady=5)
    entry_start_date = Entry(new_window)
    entry_start_date.grid(row=5, column=1)

    label_end_date = Label(new_window, text="End Date:")
    label_end_date.grid(row=6, column=0, padx=10, pady=5)
    entry_end_date = Entry(new_window)
    entry_end_date.grid(row=6, column=1)

    label_city_name = Label(new_window, text="City Name:")
    label_city_name.grid(row=7, column=0, padx=10, pady=5)
    entry_city_name = Entry(new_window)
    entry_city_name.grid(row=7, column=1)

    label_tour_id = Label(new_window, text="Tour ID:")
    label_tour_id.grid(row=8, column=0, padx=10, pady=5)
    entry_tour_id = Entry(new_window)
    entry_tour_id.grid(row=8, column=1)

    # Create Tkinter button to save the booking details
    button_save = Button(new_window, text="Save", command=lambda: save_booking(
        entry_cust_id.get(), entry_bus_id.get(), entry_hotel_id.get(),
        entry_booking_date.get(), entry_total_day.get(), entry_start_date.get(),
        entry_end_date.get(), entry_city_name.get(), entry_tour_id.get()
    ))
    button_save.grid(row=9, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_agent():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_tour_id = Label(new_window, text="Tour ID:")
    label_tour_id.grid(row=0, column=0, padx=10, pady=5)
    entry_tour_id = Entry(new_window)
    entry_tour_id.grid(row=0, column=1)

    label_agency_id = Label(new_window, text="Agency ID:")
    label_agency_id.grid(row=1, column=0, padx=10, pady=5)
    entry_agency_id = Entry(new_window)
    entry_agency_id.grid(row=1, column=1)

    label_name = Label(new_window, text="Agent Name:")
    label_name.grid(row=2, column=0, padx=10, pady=5)
    entry_name = Entry(new_window)
    entry_name.grid(row=2, column=1)

    label_telephone = Label(new_window, text="Agent Telephone:")
    label_telephone.grid(row=3, column=0, padx=10, pady=5)
    entry_telephone = Entry(new_window)
    entry_telephone.grid(row=3, column=1)

    label_salary = Label(new_window, text="Salary:")
    label_salary.grid(row=4, column=0, padx=10, pady=5)
    entry_salary = Entry(new_window)
    entry_salary.grid(row=4, column=1)

    label_available = Label(new_window, text="Available:")
    label_available.grid(row=5, column=0, padx=10, pady=5)
    entry_available = Entry(new_window)
    entry_available.grid(row=5, column=1)

    # Create Tkinter button to save the agent details
    button_save = Button(new_window, text="Save", command=lambda: save_agent(
        entry_tour_id.get(), entry_agency_id.get(), entry_name.get(), entry_telephone.get(),
        entry_salary.get(), entry_available.get()
    ))
    button_save.grid(row=6, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_city():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_city_name = Label(new_window, text="City Name:")
    label_city_name.grid(row=0, column=0, padx=10, pady=5)
    entry_city_name = Entry(new_window)
    entry_city_name.grid(row=0, column=1)

    label_plate_number = Label(new_window, text="Plate Number:")
    label_plate_number.grid(row=1, column=0, padx=10, pady=5)
    entry_plate_number = Entry(new_window)
    entry_plate_number.grid(row=1, column=1)

    label_country = Label(new_window, text="Country:")
    label_country.grid(row=2, column=0, padx=10, pady=5)
    entry_country = Entry(new_window)
    entry_country.grid(row=2, column=1)

    # Create Tkinter button to save the city details
    button_save = Button(new_window, text="Save", command=lambda: save_city(
        entry_city_name.get(), entry_plate_number.get(), entry_country.get()
    ))
    button_save.grid(row=3, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_bus():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_driver_id = Label(new_window, text="Driver ID:")
    label_driver_id.grid(row=0, column=0, padx=10, pady=5)
    entry_driver_id = Entry(new_window)
    entry_driver_id.grid(row=0, column=1)

    label_tour_id = Label(new_window, text="Tour ID:")
    label_tour_id.grid(row=1, column=0, padx=10, pady=5)
    entry_tour_id = Entry(new_window)
    entry_tour_id.grid(row=1, column=1)

    label_bus_name = Label(new_window, text="Bus Name:")
    label_bus_name.grid(row=2, column=0, padx=10, pady=5)
    entry_bus_name = Entry(new_window)
    entry_bus_name.grid(row=2, column=1)

    label_seating_capacity = Label(new_window, text="Seating Capacity:")
    label_seating_capacity.grid(row=3, column=0, padx=10, pady=5)
    entry_seating_capacity = Entry(new_window)
    entry_seating_capacity.grid(row=3, column=1)

    label_availability = Label(new_window, text="Availability:")
    label_availability.grid(row=4, column=0, padx=10, pady=5)
    entry_availability = Entry(new_window)
    entry_availability.grid(row=4, column=1)

    label_destination = Label(new_window, text="Destination:")
    label_destination.grid(row=5, column=0, padx=10, pady=5)
    entry_destination = Entry(new_window)
    entry_destination.grid(row=5, column=1)

    # Create Tkinter button to save the bus details
    button_save = Button(new_window, text="Save", command=lambda: save_bus(
        entry_driver_id.get(), entry_tour_id.get(), entry_bus_name.get(),
        entry_seating_capacity.get(), entry_availability.get(), entry_destination.get()
    ))
    button_save.grid(row=6, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_driver():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_name = Label(new_window, text="Name:")
    label_name.grid(row=0, column=0, padx=10, pady=5)
    entry_name = Entry(new_window)
    entry_name.grid(row=0, column=1)

    label_telephone = Label(new_window, text="Telephone No:")
    label_telephone.grid(row=1, column=0, padx=10, pady=5)
    entry_telephone = Entry(new_window)
    entry_telephone.grid(row=1, column=1)

    label_address = Label(new_window, text="Driver Address:")
    label_address.grid(row=2, column=0, padx=10, pady=5)
    entry_address = Entry(new_window)
    entry_address.grid(row=2, column=1)

    label_salary = Label(new_window, text="Salary:")
    label_salary.grid(row=3, column=0, padx=10, pady=5)
    entry_salary = Entry(new_window)
    entry_salary.grid(row=3, column=1)

    label_license = Label(new_window, text="License Number:")
    label_license.grid(row=4, column=0, padx=10, pady=5)
    entry_license = Entry(new_window)
    entry_license.grid(row=4, column=1)

    # Create Tkinter button to save the driver details
    button_save = Button(new_window, text="Save", command=lambda: save_driver(
        entry_name.get(), entry_telephone.get(),
        entry_address.get(), entry_salary.get(), entry_license.get()
    ))
    button_save.grid(row=5, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_hotel():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_hotel_name = Label(new_window, text="Hotel Name:")
    label_hotel_name.grid(row=0, column=0, padx=10, pady=5)
    entry_hotel_name = Entry(new_window)
    entry_hotel_name.grid(row=0, column=1)

    label_city_id = Label(new_window, text="City ID:")
    label_city_id.grid(row=1, column=0, padx=10, pady=5)
    entry_city_id = Entry(new_window)
    entry_city_id.grid(row=1, column=1)

    label_hotel_price = Label(new_window, text="Hotel Price:")
    label_hotel_price.grid(row=2, column=0, padx=10, pady=5)
    entry_hotel_price = Entry(new_window)
    entry_hotel_price.grid(row=2, column=1)

    label_hotel_telephone = Label(new_window, text="Hotel Telephone No:")
    label_hotel_telephone.grid(row=3, column=0, padx=10, pady=5)
    entry_hotel_telephone = Entry(new_window)
    entry_hotel_telephone.grid(row=3, column=1)

    label_room_count = Label(new_window, text="Room Count:")
    label_room_count.grid(row=4, column=0, padx=10, pady=5)
    entry_room_count = Entry(new_window)
    entry_room_count.grid(row=4, column=1)

    # Create Tkinter button to save the hotel details
    button_save = Button(new_window, text="Save", command=lambda: save_hotel(
        entry_hotel_name.get(), entry_city_id.get(), entry_hotel_price.get(),
        entry_hotel_telephone.get(), entry_room_count.get()
    ))
    button_save.grid(row=5, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_staff():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_agency_id = Label(new_window, text="Agency ID:")
    label_agency_id.grid(row=0, column=0, padx=10, pady=5)
    entry_agency_id = Entry(new_window)
    entry_agency_id.grid(row=0, column=1)

    label_agency_telephone = Label(new_window, text="Agency Telephone:")
    label_agency_telephone.grid(row=1, column=0, padx=10, pady=5)
    entry_agency_telephone = Entry(new_window)
    entry_agency_telephone.grid(row=1, column=1)

    label_address = Label(new_window, text="Address:")
    label_address.grid(row=2, column=0, padx=10, pady=5)
    entry_address = Entry(new_window)
    entry_address.grid(row=2, column=1)

    label_job_code = Label(new_window, text="Job Code:")
    label_job_code.grid(row=3, column=0, padx=10, pady=5)
    entry_job_code = Entry(new_window)
    entry_job_code.grid(row=3, column=1)

    label_title = Label(new_window, text="Title:")
    label_title.grid(row=4, column=0, padx=10, pady=5)
    entry_title = Entry(new_window)
    entry_title.grid(row=4, column=1)

    label_salary = Label(new_window, text="Salary:")
    label_salary.grid(row=5, column=0, padx=10, pady=5)
    entry_salary = Entry(new_window)
    entry_salary.grid(row=5, column=1)

    # Create Tkinter button to save the staff details
    button_save = Button(new_window, text="Save", command=lambda: save_staff(
        entry_agency_id.get(), entry_agency_telephone.get(), entry_address.get(),
        entry_job_code.get(), entry_title.get(), entry_salary.get()
    ))
    button_save.grid(row=6, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_tour():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_name = Label(new_window, text="Tour Name:")
    label_name.grid(row=0, column=0, padx=10, pady=5)
    entry_name = Entry(new_window)
    entry_name.grid(row=0, column=1)

    label_location = Label(new_window, text="Location:")
    label_location.grid(row=1, column=0, padx=10, pady=5)
    entry_location = Entry(new_window)
    entry_location.grid(row=1, column=1)

    label_route = Label(new_window, text="Route:")
    label_route.grid(row=2, column=0, padx=10, pady=5)
    entry_route = Entry(new_window)
    entry_route.grid(row=2, column=1)

    label_date = Label(new_window, text="Date:")
    label_date.grid(row=3, column=0, padx=10, pady=5)
    entry_date = Entry(new_window)
    entry_date.grid(row=3, column=1)

    label_duration = Label(new_window, text="Duration:")
    label_duration.grid(row=4, column=0, padx=10, pady=5)
    entry_duration = Entry(new_window)
    entry_duration.grid(row=4, column=1)

    label_capacity = Label(new_window, text="Capacity:")
    label_capacity.grid(row=5, column=0, padx=10, pady=5)
    entry_capacity = Entry(new_window)
    entry_capacity.grid(row=5, column=1)

    # Create Tkinter button to save the tour details
    button_save = Button(new_window, text="Save", command=lambda: save_tour(
        entry_name.get(), entry_location.get(), entry_route.get(),
        entry_date.get(), entry_duration.get(), entry_capacity.get()
    ))
    button_save.grid(row=6, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_travel_agency():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_agency_name = Label(new_window, text="Agency Name:")
    label_agency_name.grid(row=0, column=0, padx=10, pady=5)
    entry_agency_name = Entry(new_window)
    entry_agency_name.grid(row=0, column=1)

    label_city_id = Label(new_window, text="City ID:")
    label_city_id.grid(row=1, column=0, padx=10, pady=5)
    entry_city_id = Entry(new_window)
    entry_city_id.grid(row=1, column=1)

    label_phone = Label(new_window, text="Phone:")
    label_phone.grid(row=2, column=0, padx=10, pady=5)
    entry_phone = Entry(new_window)
    entry_phone.grid(row=2, column=1)

    label_address = Label(new_window, text="Address:")
    label_address.grid(row=3, column=0, padx=10, pady=5)
    entry_address = Entry(new_window)
    entry_address.grid(row=3, column=1)

    label_city = Label(new_window, text="City:")
    label_city.grid(row=4, column=0, padx=10, pady=5)
    entry_city = Entry(new_window)
    entry_city.grid(row=4, column=1)

    label_mail = Label(new_window, text="Mail:")
    label_mail.grid(row=5, column=0, padx=10, pady=5)
    entry_mail = Entry(new_window)
    entry_mail.grid(row=5, column=1)

    # Create Tkinter button to save the travel agency details
    button_save = Button(new_window, text="Save", command=lambda: save_travel_agency(
        entry_agency_name.get(), entry_city_id.get(), entry_phone.get(),
        entry_address.get(), entry_city.get(), entry_mail.get()
    ))
    button_save.grid(row=6, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_booking():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_booking_id = Label(new_window, text="Booking ID:")
    label_booking_id.grid(row=0, column=0, padx=10, pady=5)
    entry_booking_id = Entry(new_window)
    entry_booking_id.grid(row=0, column=1)

    # Create Tkinter button to delete a booking
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('booking',entry_booking_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_customer():
    # Open a new window for deleting a customer
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Customer ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the customer
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity_customer('customer', 'custID', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_agents():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Agent ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the agent
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('agent', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_buses():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Bus ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the bus
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('bus', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_cities():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="City ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the city
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('city', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_hotels():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Hotel ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the hotel
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('hotel', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_staff():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Staff ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the staff
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('staff', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_drivers():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Driver ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the driver
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('driver', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_tours():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Tour ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the tour
    button_delete = Button(new_window, text="Delete", command=lambda: delete_entity('tour', entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def open_new_window_delete_agencies():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_id = Label(new_window, text="Agency ID:")
    label_id.grid(row=0, column=0, padx=10, pady=5)
    entry_id = Entry(new_window)
    entry_id.grid(row=0, column=1)

    # Create Tkinter button to delete the agency
    button_delete = Button(new_window, text="Delete", command=lambda: delete_agency(entry_id.get()))
    button_delete.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def delete_agency(agency_id):
    cursor = db.cursor()
    sql = "DELETE FROM travelagency WHERE agencyID = %s"
    val = (agency_id,)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Travel Agency deleted successfully")

# %%
def delete_entity(entity, entity_id):
    cursor = db.cursor()
    sql = f"DELETE FROM {entity} WHERE {entity}ID = %s"
    val = (entity_id,)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", f"{entity.capitalize()} deleted successfully")

# %%
def delete_entity_customer(entity, entity_id_column, entity_id):
    try:
        cursor = db.cursor()
        sql = f"DELETE FROM {entity} WHERE {entity_id_column} = %s"
        val = (entity_id,)
        cursor.execute(sql, val)
        db.commit()
        messagebox.showinfo("Success", f"{entity.capitalize()} deleted successfully")
    except mysql.connector.Error as error:
        messagebox.showerror("Error", str(error))

# %%
def save_customer(name, surname, contact, gender, reg_date, address):
    cursor = db.cursor()
    sql = "INSERT INTO customer (custName, custSurname, contactDetails, gender, birthday, custAddress) VALUES (%s, %s, %s, %s, %s, %s)"
    val = (name, surname, contact, gender, reg_date, address)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Customer added successfully")

# %%
def save_agent(tour_id, agency_id, name, telephone, salary, available):
    cursor = db.cursor()
    sql = "INSERT INTO agent (tourID, agencyID, agentName, agentTelephone, salary, available) VALUES (%s, %s, %s, %s, %s, %s)"
    val = (tour_id, agency_id, name, telephone, salary, available)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Agent added successfully")

# %%
def save_booking(cust_id, bus_id, hotel_id, booking_date, total_day, start_date, end_date, city_name, tour_id):
    cursor = db.cursor()
    sql = "INSERT INTO booking (custID, busID, hotelID, bookingDate, totalDay, startDate, endDate, cityName, tourID) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
    val = (cust_id, bus_id, hotel_id, booking_date, total_day, start_date, end_date, city_name, tour_id)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Booking added successfully")

# %%
def save_bus(driver_id, tour_id, bus_name, seating_capacity, availability, destination):
    cursor = db.cursor()
    sql = "INSERT INTO bus (driverID, tourID, busName, seatingCapacity, availability, destination) VALUES (%s, %s, %s, %s, %s, %s)"
    val = (driver_id, tour_id, bus_name, seating_capacity, availability, destination)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Bus added successfully")

# %%
def save_city(city_name, plate_number, country):
    cursor = db.cursor()
    sql = "INSERT INTO city (cityName, plateNumber, country) VALUES (%s, %s, %s)"
    val = (city_name, plate_number, country)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "City added successfully")

# %%
def save_driver(name, telephone, address, salary, license):
    cursor = db.cursor()
    sql = "INSERT INTO driver (driverName, telephoneNo, driverAdress, salary, licenseNumber) VALUES (%s, %s, %s, %s, %s)"
    val = (name, telephone, address, salary, license)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Driver added successfully")

# %%
def save_hotel(name, city_id, price, telephone_no, room_count):
    cursor = db.cursor()
    sql = "INSERT INTO hotel (hotelName, cityID, hotelPrice, hotelTelephoneNo, roomCount) VALUES (%s, %s, %s, %s, %s)"
    val = (name, city_id, price, telephone_no, room_count)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Hotel added successfully")

# %%
def save_staff(agency_id, agency_telephone, address, job_code, title, salary):
    cursor = db.cursor()
    sql = "INSERT INTO staff (agencyID, agencyTelephone, adress, jobCode, title, salary) VALUES (%s, %s, %s, %s, %s, %s)"
    val = (agency_id, agency_telephone, address, job_code, title, salary)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Staff added successfully")

# %%
def save_tour(name, location, route, date, duration, capacity):
    cursor = db.cursor()
    sql = "INSERT INTO tour (tourName, location, route, time, duration, capacity) VALUES (%s, %s, %s, %s, %s, %s)"
    val = (name, location, route, date, duration, capacity)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Tour added successfully")

# %%
def save_travel_agency(name, city_id, phone, address, city, mail):
    cursor = db.cursor()
    sql = "INSERT INTO travelagency (agencyName, cityID, phone, address, city, mail) VALUES (%s, %s, %s, %s, %s, %s)"
    val = (name, city_id, phone, address, city, mail)
    cursor.execute(sql, val)
    db.commit()
    messagebox.showinfo("Success", "Travel agency added successfully")

# %%
def display_agents():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM agent")
    agents = cursor.fetchall()
    
    # Create a new window to display the agents
    new_window = Toplevel(window)
    
    # Create columns for the Treeview
    columns = ("ID", "Tour ID", "Agency ID", "Name", "Telephone", "Salary", "Available")
    
    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")
    
    # Set column headings
    for col in columns:
        tree.heading(col, text=col)
    
    # Insert agent records into the Treeview
    for agent in agents:
        tree.insert("", "end", values=agent)
    
    # Display the Treeview widget
    tree.pack()

# %%
def display_bookings():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM booking")
    bookings = cursor.fetchall()

    # Create a new window to display the bookings
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Booking ID", "Customer ID", "Bus ID", "Hotel ID", "Booking Date", "Total Day", "Room ID", "Start Date", "End Date", "City Name","Tour ID")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert booking records into the Treeview
    for booking in bookings:
        tree.insert("", "end", values=booking)

    # Display the Treeview widget
    tree.pack()

# %%
def display_buses():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM bus")
    buses = cursor.fetchall()

    # Create a new window to display the buses
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Bus ID", "Driver ID", "Tour ID", "Bus Name", "Seating Capacity", "Availability", "Destination")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert bus records into the Treeview
    for bus in buses:
        tree.insert("", "end", values=bus)

    # Display the Treeview widget
    tree.pack()

# %%
def display_customers():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM customer")
    customers = cursor.fetchall()

    # Create a new window to display the customers
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Customer ID", "Name", "Surname", "Contact", "Gender", "Registration Date", "Address")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert customer records into the Treeview
    for customer in customers:
        tree.insert("", "end", values=customer)

    # Display the Treeview widget
    tree.pack()

# %%
def display_cities():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM city")
    cities = cursor.fetchall()

    # Create a new window to display the cities
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("City ID", "City Name", "Plate Number", "Country")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert city records into the Treeview
    for city in cities:
        tree.insert("", "end", values=city)

    # Display the Treeview widget
    tree.pack()

# %%
def display_hotels():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM hotel")
    hotels = cursor.fetchall()

    # Create a new window to display the hotels
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Hotel ID", "Hotel Name", "City ID", "Hotel Price", "Hotel Telephone No", "Room Count")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert hotel records into the Treeview
    for hotel in hotels:
        tree.insert("", "end", values=hotel)

    # Display the Treeview widget
    tree.pack()

# %%
def display_staff():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM staff")
    staffs = cursor.fetchall()

    # Create a new window to display the staff
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Staff ID", "Staff Name", "Position", "Telephone", "Job Code","Title","Salary")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert staff records into the Treeview
    for staff in staffs:
        tree.insert("", "end", values=staff)

    # Display the Treeview widget
    tree.pack()

# %%
def display_drivers():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM driver")
    drivers = cursor.fetchall()

    # Create a new window to display the drivers
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Driver ID", "Driver Name", "Telephone", "Address", "Salary", "License Number")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert driver records into the Treeview
    for driver in drivers:
        tree.insert("", "end", values=driver)

    # Display the Treeview widget
    tree.pack()

# %%
def display_tours():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM tour")
    tours = cursor.fetchall()

    # Create a new window to display the tours
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Tour ID", "Hotel ID", "Tour Name", "Location", "Route", "Time", "Duration", "Capacity")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert tour records into the Treeview
    for tour in tours:
        tree.insert("", "end", values=tour)

    # Display the Treeview widget
    tree.pack()

# %%
def display_travel_agencies():
    cursor = db.cursor()
    cursor.execute("SELECT * FROM travelagency")
    travel_agencies = cursor.fetchall()

    # Create a new window to display the travel agencies
    new_window = Toplevel(window)

    # Create columns for the Treeview
    columns = ("Agency ID", "Agency Name", "City ID", "Phone", "Address", "City", "Mail")

    # Create a Treeview widget
    tree = ttk.Treeview(new_window, columns=columns, show="headings")

    # Set column headings
    for col in columns:
        tree.heading(col, text=col)

    # Insert travel agency records into the Treeview
    for agency in travel_agencies:
        tree.insert("", "end", values=agency)

    # Display the Treeview widget
    tree.pack()

# %%
def open_new_window_update_salary():
    new_window = Toplevel(window)
    new_window.title("Update Staff Salaries")
    
    label_rate = Label(new_window, text="Enter new salary rate:")
    label_rate.grid(row=0, column=0, padx=10, pady=5)
    
    entry_rate = Entry(new_window)
    entry_rate.grid(row=0, column=1, padx=10, pady=5)
    
    button_save = Button(new_window, text="Save", command=lambda: save_rate(entry_rate.get()))
    button_save.grid(row=1, column=0, columnspan=2, padx=10, pady=5)

# %%
def save_rate(rate):
    cursor = db.cursor()
    cursor.callproc('updateStaffSalaries', (int(rate),))
    db.commit()
    messagebox.showinfo("Procedure", "Update Staff Salary executed successfully")

# %%
def open_new_window_update_tour():
    new_window = Toplevel(window)
    new_window.title("Update Tour Route")

    # Create Tkinter labels and entry widgets in the new window
    label_tour_id = Label(new_window, text="Enter Tour ID:")
    label_tour_id.grid(row=0, column=0, padx=10, pady=5)

    entry_tour_id = Entry(new_window)
    entry_tour_id.grid(row=0, column=1, padx=10, pady=5)

    label_route = Label(new_window, text="Enter new route:")
    label_route.grid(row=1, column=0, padx=10, pady=5)

    entry_route = Entry(new_window)
    entry_route.grid(row=1, column=1, padx=10, pady=5)

    button_save = Button(new_window, text="Save", command=lambda: save_route(entry_tour_id.get(), entry_route.get()))
    button_save.grid(row=2, column=0, columnspan=2, padx=10, pady=5)

# %%
def save_route(tour_id, route):
    cursor = db.cursor()
    cursor.callproc('updateTourRoute', (int(tour_id), route))
    db.commit()
    messagebox.showinfo("Procedure", "updateTourRoute executed successfully")

# %%
def open_new_window_update_customer():
    new_window = Toplevel(window)
    new_window.title("Update Customer Name")

    # Create Tkinter labels and entry widgets in the new window
    label_customer_id = Label(new_window, text="Enter Customer ID:")
    label_customer_id.grid(row=0, column=0, padx=10, pady=5)

    entry_customer_id = Entry(new_window)
    entry_customer_id.grid(row=0, column=1, padx=10, pady=5)

    label_name = Label(new_window, text="Enter new name:")
    label_name.grid(row=1, column=0, padx=10, pady=5)

    entry_name = Entry(new_window)
    entry_name.grid(row=1, column=1, padx=10, pady=5)

    button_save = Button(new_window, text="Save", command=lambda: save_customer_name(entry_customer_id.get(), entry_name.get()))
    button_save.grid(row=2, column=0, columnspan=2, padx=10, pady=5)

# %%
def save_customer_name(customer_id, name):
    cursor = db.cursor()
    cursor.callproc('updateCustomerName', (int(customer_id), name))
    db.commit()
    messagebox.showinfo("Procedure", "updateCustomerName executed successfully")

# %%
def open_new_window_update_duration():
    new_window = Toplevel(window)

    # Create Tkinter labels and entry widgets in the new window
    label_tour_id = Label(new_window, text="Tour ID:")
    label_tour_id.grid(row=0, column=0, padx=10, pady=5)
    entry_tour_id = Entry(new_window)
    entry_tour_id.grid(row=0, column=1)

    label_duration = Label(new_window, text="New Duration:")
    label_duration.grid(row=1, column=0, padx=10, pady=5)
    entry_duration = Entry(new_window)
    entry_duration.grid(row=1, column=1)

    # Create Tkinter button to update the tour duration
    button_update_duration = Button(new_window, text="Update Duration", command=lambda: update_tour_duration(
        entry_tour_id.get(), entry_duration.get()
    ))
    button_update_duration.grid(row=2, column=0, columnspan=2, padx=10, pady=5)

# %%
def update_tour_duration(tour_id, new_duration):
    try:
        cursor = db.cursor()
        sql = "UPDATE tour SET duration = %s WHERE tourID = %s"
        val = (new_duration, tour_id)
        cursor.execute(sql, val)
        db.commit()
        messagebox.showinfo("Success", "Tour duration updated successfully")
    except mysql.connector.Error as error:
        messagebox.showerror("Error", str(error))

# %%
def clear_table():
    for record in tree.get_children():
        tree.delete(record)

# %%
db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="BJK_li_MAK",
    database="touragency"
)

# %%
window = Tk()

# %%
button_display = Button(window, text="Display Customers", command=display_customers)
button_display.grid(row=2, column=0, padx=10, pady=5)
button_add = Button(window, text="Add Customer", command=open_new_window_customer)
button_add.grid(row=3, column=0, padx=10, pady=5)
button_bookings = Button(window, text="Delete Customer", command=open_new_window_delete_customer)
button_bookings.grid(row=4, column=0, padx=10, pady=5)

button_display = Button(window, text="Display Agents", command=display_agents)
button_display.grid(row=2, column=1, padx=10, pady=5)
button_add = Button(window, text="Add Agent", command=open_new_window_agent)
button_add.grid(row=3, column=1, padx=10, pady=5)
button_bookings = Button(window, text="Delete Agent", command=open_new_window_delete_agents)
button_bookings.grid(row=4, column=1, padx=10, pady=5)

button_display = Button(window, text="Display Buses", command=display_buses)
button_display.grid(row=2, column=2, padx=10, pady=5)
button_display = Button(window, text="Add Buses", command=open_new_window_bus)
button_display.grid(row=3, column=2, padx=10, pady=5)
button_bookings = Button(window, text="Delete Bookings", command=open_new_window_delete_buses)
button_bookings.grid(row=4, column=2, padx=10, pady=5)

button_display = Button(window, text="Display Bookings", command=display_bookings)
button_display.grid(row=2, column=3, padx=10, pady=5)
button_bookings = Button(window, text="Add Bookings", command=open_new_window_booking)
button_bookings.grid(row=3, column=3, padx=10, pady=5)
button_bookings = Button(window, text="Delete Bookings", command=open_new_window_delete_booking)
button_bookings.grid(row=4, column=3, padx=10, pady=5)

button_display = Button(window, text="Display Cities", command=display_cities)
button_display.grid(row=2, column=4, padx=10, pady=5)
button_display = Button(window, text="Add City", command=open_new_window_city)
button_display.grid(row=3, column=4, padx=10, pady=5)
button_bookings = Button(window, text="Delete City", command=open_new_window_delete_cities)
button_bookings.grid(row=4, column=4, padx=10, pady=5)

button_display = Button(window, text="Display Hotels", command=display_hotels)
button_display.grid(row=2, column=5, padx=10, pady=5)
button_display = Button(window, text="Add Hotel", command=open_new_window_hotel)
button_display.grid(row=3, column=5, padx=10, pady=5)
button_bookings = Button(window, text="Delete Hotel", command=open_new_window_delete_hotels)
button_bookings.grid(row=4, column=5, padx=10, pady=5)

button_display = Button(window, text="Display Staff", command=display_staff)
button_display.grid(row=2, column=6, padx=10, pady=5)
button_display = Button(window, text="Add Staff", command=open_new_window_staff)
button_display.grid(row=3, column=6, padx=10, pady=5)
button_bookings = Button(window, text="Delete Staff", command=open_new_window_delete_staff)
button_bookings.grid(row=4, column=6, padx=10, pady=5)

button_display = Button(window, text="Display Drivers", command=display_drivers)
button_display.grid(row=2, column=7, padx=10, pady=5)
button_display = Button(window, text="Add Driver", command=open_new_window_driver)
button_display.grid(row=3, column=7, padx=10, pady=5)
button_bookings = Button(window, text="Delete Driver", command=open_new_window_delete_drivers)
button_bookings.grid(row=4, column=7, padx=10, pady=5)

button_display = Button(window, text="Display Tours", command=display_tours)
button_display.grid(row=2, column=8, padx=10, pady=5)
button_display = Button(window, text="Add Tour", command=open_new_window_tour)
button_display.grid(row=3, column=8, padx=10, pady=5)
button_bookings = Button(window, text="Delete Tour", command=open_new_window_delete_tours)
button_bookings.grid(row=4, column=8, padx=10, pady=5)

button_display = Button(window, text="Display Travel Agencies", command=display_travel_agencies)
button_display.grid(row=2, column=9, padx=10, pady=5)
button_display = Button(window, text="Add Travel Agency", command=open_new_window_travel_agency)
button_display.grid(row=3, column=9, padx=10, pady=5)
button_bookings = Button(window, text="Delete Travel Agency", command=open_new_window_delete_agencies)
button_bookings.grid(row=4, column=9, padx=10, pady=5)

button_update_staff_salaries = Button(window, text="Update Staff Salaries", command=open_new_window_update_salary)
button_update_staff_salaries.grid(row=10, column=0, pady=10)
button_update_tour_route = Button(window, text="Update Tour Route", command=open_new_window_update_tour)
button_update_tour_route.grid(row=10, column=1, pady=10)
button_update_customer_name = Button(window, text="Update Customer Name", command=open_new_window_update_customer)
button_update_customer_name.grid(row=10, column=2, pady=10)
button_update_duration = Button(window, text="Update Tour Duration", command=open_new_window_update_duration)
button_update_duration.grid(row=10, column=3, pady=10)

# %%
window.mainloop()

# %%
db.close()
